# %% [markdown]
# <a href="https://colab.research.google.com/github/Clinton1029/Iris_ml/blob/main/Iris_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Libraries

# %%
# Import libraries
import os
import pandas as pd

# %% [markdown]
# ## Explanatory Data Analysis

# %%
# The Dimension of Data

df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3602/1102550035.py in <cell line: 0>()
#       1 # The Dimension of Data
#       2
# ----> 3 df.shape
#
# NameError: name 'df' is not defined

# %%
## Genaral Data Information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# Statistical Description of the Data

df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ## Load the data

# %%
# Loading the data

# File path
file_path = "/content/Iris (1).csv"

# Check if the file exists
if os.path.exists(file_path):
    print("File exists.")
    # Load the dataset into a DataFrame
    df=pd.read_csv(file_path)
    print(df)

else:
    print("File does not exist.")
# Out:
# File exists.
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %% [markdown]
# ## Data Processing and cleaning

# %%
#checking null value

df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# checking the duplicates

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# check the datatype

df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
# Label encode the target variable (species)
df["species_encoded"] = df["Species"].astype("category").cat.codes


# Display original and encoded target variable
df[["Species", "species_encoded"]].head()
# Out:
#        Species  species_encoded
# 0  Iris-setosa                0
# 1  Iris-setosa                0
# 2  Iris-setosa                0
# 3  Iris-setosa                0
# 4  Iris-setosa                0
